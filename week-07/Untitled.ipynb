# %% [markdown]
# # Exercise 2.A Fundamentals of pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Series
#
# In this section, we create Python objects and convert them into pandas Series.

# %%
aa = [1, 2, 3, 4]

ab = (5, 6, 7, 8)

ac = {9, 10, 11, 12}

ad = {
    "first": 13,
    "second": 14,
    "third": 15,
    "fourth": 16
}

print("aa:", aa)
print("ab:", ab)
print("ac:", ac)
print("ad:", ad)
# Out:
# aa: [1, 2, 3, 4]
# ab: (5, 6, 7, 8)
# ac: {9, 10, 11, 12}
# ad: {'first': 13, 'second': 14, 'third': 15, 'fourth': 16}

# %% [markdown]
# Now we convert each Python object into a pandas Series.

# %%
ser1 = pd.Series(aa)

ser2 = pd.Series(ab)

ser3 = pd.Series(list(ac))

ser4 = pd.Series(ad)

print("ser1:")
print(ser1)

print("\nser2:")
print(ser2)

print("\nser3:")
print(ser3)

print("\nser4:")
print(ser4)
# Out:
# ser1:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
#
# ser2:
# 0    5
# 1    6
# 2    7
# 3    8
# dtype: int64
#
# ser3:
# 0     9
# 1    10
# 2    11
# 3    12
# dtype: int64
#
# ser4:
# first     13
# second    14
# third     15
# fourth    16
# dtype: int64

# %% [markdown]
# Now we try to create a Series using literal values directly.

# %%
ser5 = pd.Series(17, 18, 19, 20)

# This code will produce an error because pd.Series expects one main data object,
# not several separate values
# TypeError: Series.__init__() takes from 1 to 2 positional arguments but 5 were given
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ser5 = pd.Series(17, 18, 19, 20)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\series.py:423, in Series.__init__(self, data, index, dtype, name, copy)
#     420 name = ibase.maybe_extract_name(name, data, type(self))
#     422 if index is not None:
# --> 423     index = ensure_index(index)
#     425 if dtype is not None:
#     426     dtype = self._validate_dtype(dtype)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:7975, in ensure_index(index_like, copy)
#    7973         return Index(index_like, copy=copy, tupleize_cols=False)
#    7974 else:
# -> 7975     return Index(index_like, copy=copy)
#
# ...

# %% [markdown]
# ## DataFrames from Series
#
# In this section, we create a DataFrame from Series objects.

# %%
df1 = pd.DataFrame(ser1)

df1
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %% [markdown]
# Now we add two new columns to the DataFrame using the insert() method.

# %%
df1.insert(1, "ser2", ser2)

df1.insert(2, "ser3", ser3)

df1
# Out:
#    0  ser2  ser3
# 0  1     5     9
# 1  2     6    10
# 2  3     7    11
# 3  4     8    12

# %% [markdown]
# Now we add a third new column using ser4.

# %%
df1["ser4"] = ser4

df1

# ser4 is different because it was created from a dictionary.
# Its index labels are "first", "second", "third", and "fourth".
# The other Series use number indexes 0, 1, 2, and 3.
# Because the indexes do not match, pandas shows NaN values
# Out:
#    0  ser2  ser3  ser4
# 0  1     5     9   NaN
# 1  2     6    10   NaN
# 2  3     7    11   NaN
# 3  4     8    12   NaN

# %% [markdown]
# Now we add a new row using the loc attribute.

# %%
df1.loc[4] = [5, 9, 12, 0]

df1
# Out:
#    0  ser2  ser3  ser4
# 0  1     5     9   NaN
# 1  2     6    10   NaN
# 2  3     7    11   NaN
# 3  4     8    12   NaN
# 4  5     9    12   0.0
