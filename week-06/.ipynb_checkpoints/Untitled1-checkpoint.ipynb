# %% [markdown]
# # Data Analytics Notes

# %% [markdown]
# ## Gaols
# - Cean data
# - Analyze trends
# - Build model

# %% [markdown]
# ## Sample Code

# %%
''' python '''
x = 10
y = 20
print(x + y)
# Out:
# 30
